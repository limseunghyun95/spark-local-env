# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession.builder
    .appName('AnatomySpark3')
    .master('spark://spark-master:7077')
    .getOrCreate()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/30 05:06:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/10/30 05:06:52 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/10/30 05:06:52 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/10/30 05:06:52 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.

# %%
spark.conf.set("spark.driver.memory", "2g")
spark.conf.set("spark.executor.memory", "2g")
spark.conf.set("spark.executor.cores", "2")
spark.conf.set("spark.sql.shuffle.partitions", "8")
spark.conf.set("date", "2025-10-30")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 spark.conf.set("spark.driver.memory", "2g")
#       2 spark.conf.set("spark.executor.memory", "2g")
#       3 spark.conf.set("spark.executor.cores", "2")
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/sql/conf.py:43, in RuntimeConfig.set(self, key, value)
#      40 @since(2.0)
#      41 def set(self, key: str, value: Union[str, int, bool]) -> None:
#      42     """Sets the given Spark runtime configuration property."""
# ---> 43     self._jconf.set(key, value)
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [CANNOT_MODIFY_CONFIG] Cannot modify the value of the Spark config: "spark.driver.memory".
# See also 'https://spark.apache.org/docs/latest/sql-migration-guide.html#ddl-statements'.

# %%
print(spark.conf.get("date"))
# Out:
# 2025-10-30

# %%
spark.stop()
