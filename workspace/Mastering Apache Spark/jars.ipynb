# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession.builder
    .appName("JarExample")
    .config("spark.jars", "/opt/spark/extra-jars/iceberg-spark-runtime-3.5_2.12-1.10.0.jar")
    .getOrCreate()
)
# Out:
# 25/10/30 06:58:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/30 06:58:22 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/10/30 06:58:22 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/10/30 06:58:22 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 25/10/30 06:58:22 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.

# %%
sc= spark.sparkContext

# %%
sc.addJar('/opt/spark/extra-jars/hadoop-aws-3.4.2.jar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sc.addJar('/opt/spark/extra-jars/hadoop-aws-3.4.2.jar')
#
# AttributeError: 'SparkContext' object has no attribute 'addJar'
