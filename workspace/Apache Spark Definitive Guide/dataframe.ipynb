# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("DataFrame") \
    .master("spark://spark-master:7077") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/08 00:15:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
row = spark.range(2).collect()
print(type(row))
print(row)
# Out:
# [Stage 0:>                                                          (0 + 2) / 2]
# <class 'list'>
# [Row(id=0), Row(id=1)]

# %%
# Out:
# <class 'list'>
# [Row(id=0), Row(id=1)]
